# %% [markdown]
# # Clase 04 — Estadística descriptiva para decisiones iniciales
#
# Objetivo: Interpretar métricas descriptivas simples y relacionarlas con preguntas reales.

# %%
from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "retencion_clientes.csv")
df.describe(numeric_only=True)

# %% [markdown]
# ## Desafío
# Explica con una frase qué observas y qué decisión o acción sugerirías.
