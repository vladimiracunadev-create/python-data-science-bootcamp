# %% [markdown]
# # Soluciones — Clase 04 — Estadística descriptiva para decisiones iniciales

# %%
# Qué hace: carga el dataset base y deja la tabla lista para inspección o limpieza.
# Para qué sirve: asegura que el análisis parta desde una fuente común y verificable.

from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "retencion_clientes.csv")
df.describe(numeric_only=True)
print("Solución guiada completada")
