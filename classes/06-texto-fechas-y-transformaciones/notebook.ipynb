# %% [markdown]
# # Clase 06 — Texto, fechas y transformaciones útiles
#
# Objetivo: Transformar columnas de texto y fecha para habilitar análisis más claros.

# %%
from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "soporte_tickets.csv")
df["categoria_normalizada"] = df["categoria"].str.lower()
df[["categoria", "categoria_normalizada"]].head()

# %% [markdown]
# ## Desafío
# Explica con una frase qué observas y qué decisión o acción sugerirías.
