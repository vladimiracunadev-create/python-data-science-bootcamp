# %% [markdown]
# # Clase 05 — Visualización con matplotlib
#
# Objetivo: Construir gráficos básicos y explicar qué historia cuentan los datos.

# %%
from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "retencion_clientes.csv")
plt.figure(figsize=(8,4))
plt.bar(df["mes"], df["nuevos_clientes"])
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# ## Desafío
# Explica con una frase qué observas y qué decisión o acción sugerirías.
