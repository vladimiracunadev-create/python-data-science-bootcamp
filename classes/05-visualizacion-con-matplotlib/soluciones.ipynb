# %% [markdown]
# # Soluciones — Clase 05 — Visualización con matplotlib

# %%
# Qué hace: carga datos, calcula un resumen y lo convierte en una visualización.
# Para qué sirve: hace visible el patrón principal antes de pasar a una interpretaci?n más detallada.

from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "retencion_clientes.csv")
plt.figure(figsize=(8,4))
plt.bar(df["mes"], df["nuevos_clientes"])
plt.xticks(rotation=45)
plt.tight_layout()
print("Solución guiada completada")
