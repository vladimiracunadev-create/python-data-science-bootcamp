# %% [markdown]
# # Clase 07 — Mini proyecto guiado de análisis
#
# Objetivo: Resolver un caso pequeño con preguntas, limpieza básica y visualización.

# %%
from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "ventas_tienda.csv")
resumen = df.groupby("categoria")["unidades"].sum()
resumen

# %% [markdown]
# ## Desafío
# Explica con una frase qué observas y qué decisión o acción sugerirías.
