# %% [markdown]
# # Soluciones — Clase 07 — Mini proyecto guiado de análisis

# %%
from pathlib import Path
df = pd.read_csv(Path.cwd() / "datasets" / "ventas_tienda.csv")
resumen = df.groupby("categoria")["unidades"].sum()
resumen
print("Solución guiada completada")
