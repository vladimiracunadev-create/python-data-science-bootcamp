# %% [markdown]
# # Soluciones — Clase 08 — Presentación de hallazgos con claridad

# %%
# Qué hace: ordena un mensaje ejecutivo con hallazgo, evidencia y recomendación.
# Para qué sirve: entrena la traducción del análisis técnico a una decisión comunicable.

hallazgos = ["Los clientes activos aumentan mes a mes.", "La pérdida mensual se mantiene bajo 8% en gran parte del período.", "El ingreso promedio sube de forma consistente."]
for item in hallazgos:
    print("-", item)
print("Solución guiada completada")
